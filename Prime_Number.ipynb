# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishan402/Python-Applied-AI/blob/main/Prime_Number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Check whether it is prime or not")
num = int(input("Enter any number : \n"))

flag = False
index =2

if(num==0 or num==1):
  print("{} is neither prime nor composite number".format(num))

else:
 
  while(index<num):
    if(num % index == 0):
      flag = True
      print("{} is divisible by {}".format(num, index))
    index+=1

  if(flag==True):
    print("{} is a composite number".format(num))
  else:
    print("{} is a prime number".format(num))
# Out:
# Check whether it is prime or not
# Enter any number :
# 11
# 11 is a prime number
