# %%
#Sort words in alphabetic orders

name = "python Programme to sort words in Alphabetic Order"
word = name.split()
word.sort()

for words in word:
    print(words)
# Out:
# Alphabetic
# Order
# Programme
# in
# python
# sort
# to
# words
