# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishan402/Python-Applied-AI/blob/main/Python_Quiz_99_9_wont_get_this_right!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = []
for i in range(10):
    a.append(i * ++i)
for a[i] in a: 
    print(a[i])
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 64
